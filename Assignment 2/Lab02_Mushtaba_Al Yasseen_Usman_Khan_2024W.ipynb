# %% [markdown]
# <!-- DON'T EDIT THIS CELL! -->
# <!-- TYPE SHIFT+ENTER AND GO TO THE NEXT CELL -->
#
# <img src="data:image/png;base64,..." />

# %% [markdown]
# # ENCM 509 - Lab 2 Report

# %% [markdown]
# **Student Names**
#
#
# **Mushtaba Al Yasseen (30094000)**
# \
# **Usman Khan (30092202)**

# %% [markdown]
# Importing all necessary libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits import mplot3d
import pandas as pd
from scipy.stats import norm

# to keep a good size for the plot figure, not the plot area!
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})

# %% [markdown]
# # **Introduction:**
#
# The purpose of this lab is to utilize statistical analysis to distinguish between "genuine" and "imposter" written signatures. Before applying statistical analysis, we will be collecting written signatures using the _Wacom Intuos_ tablet. We'll use this tablet to capture coordinate and pressure values at 200 points/sec as the pen moves across the tablet. The tablet is also capable of recognizing 1024 levels of pressure which will be especially useful in statistical analysis later on. In addition, we'll also utilize the software _SigGet_ to collect and convert the data to CSV files collected by the tablet. Throughout the lab we will utilize these CSV file samples to plot histograms, 2D and 3D colormaps, as well as normal distributions of both velocity and pressure and the calculation of both mean $(\mu)$ and standard deviation $(\sigma)$ in order to understand and compare trends in the distribution/dispersion of the data between both "genuine" and "imposter" written signatures to see how they differ.

# %% [markdown]
# ## **Exercise 1:**

# %% [markdown]
# First, we will plot a histogram and normal distribution curve using a set of 80 samples and 10 bins with $\mu = 50$ and $\sigma = 5$

# %%
# Theorectical Mean and Stddev
mu = 50
std = 5

# Drawing 80 samples from a normal distribution
pop_norm = norm.rvs(mu, std, size=80)
pop_norm
# Out:
# array([58.9943924 , 44.45269198, 53.18946516, 52.26469113, 46.88645536,
#        47.82815834, 50.75530946, 53.13173185, 52.58734341, 51.29399381,
#        57.94140476, 47.4787579 , 57.96406173, 49.78460615, 47.6799391 ,
#        49.28006264, 48.02031251, 51.79113995, 50.66359404, 49.16911792,
#        49.91853411, 46.22774329, 45.54572877, 50.36250997, 51.68093328,
#        48.78310481, 40.88176046, 56.68224368, 45.54633226, 48.85034713,
#        48.9727216 , 51.06099126, 54.42436882, 41.97274688, 43.62427124,
#        52.35413091, 56.70962281, 59.02032743, 64.20525024, 41.56737017,
#        49.72627216, 48.99151082, 54.03891901, 50.36552196, 43.8960748 ,
#        54.56986633, 46.53014876, 50.10637177, 47.1067352 , 50.02299427,
#        54.46392056, 53.02810837, 48.16280227, 49.77081278, 48.37757031,
#        49.08760818, 45.4681916 , 50.31604949, 43.32102375, 47.20538961,
#        51.81642753, 55.07786003, 46.31154333, 50.53204553, 49.18821225,
#        45.86586664, 43.31683024, 43.63837915, 46.52009422, 55.9904502 ,
#        51.85658193, 50.81204113, 52.97098417, 53.06291023, 47.05055826,
#        43.03895756, 49.71226957, 48.70306783, 55.45012534, 51.37807179])

# %%
# Plotting a histogram considering 10 bins of data
plt.hist(pop_norm, bins=10, density=True);
plt.title('Histogram - 10 Bins of Data')
print('REAL mean: %.2f; std: %.2f' % (np.mean(pop_norm), np.std(pop_norm)))
# Out:
# REAL mean: 50.13; std: 4.94

# %% [markdown]
# Now we'll plot a histogram and normal distribution curve using a set of 1000 samples with $\mu = 50$ and $\sigma = 5$

# %%
# Theorectical Mean and Stddev
mu = 50
std = 5

# Drawing 1000 samples from a normal distribution
pop_norm = norm.rvs(mu, std, size=1000)
pop_norm
# Out:
# array([49.84061575, 49.73763178, 50.34304604, 52.13388964, 55.72098275,
#        43.14102342, 60.38701603, 59.66001307, 51.9835895 , 55.6498853 ,
#        52.06049042, 48.62859977, 53.05650674, 55.95573573, 61.0122772 ,
#        56.20492524, 46.22944328, 52.46575142, 51.35995094, 49.31760258,
#        48.68430177, 56.53017154, 47.40761443, 57.6548897 , 48.61203788,
#        54.68592875, 47.361025  , 59.22603291, 45.87353475, 54.29867523,
#        51.42851432, 49.29476031, 45.88270371, 51.61373254, 52.93696931,
#        45.93432807, 52.98647158, 48.73550487, 43.28860209, 45.11655877,
#        55.36181965, 49.47986234, 53.086531  , 48.69739133, 41.6246924 ,
#        47.32328025, 51.8727378 , 51.78716397, 45.41932401, 54.96676596,
#        47.47498467, 50.34215386, 51.35004183, 47.3539484 , 47.06541772,
#        51.27095516, 50.38555401, 53.01390001, 49.17608452, 49.15125333,
#        51.43427797, 51.62403944, 54.81239049, 48.44767715, 45.16658564,
#        47.74208738, 55.30376272, 54.02102793, 43.90439011, 44.1232319 ,
#        51.59222334, 55.53224495, 53.45366881, 51.59663735, 51.78401449,
#        42.52184761, 41.02568606, 51.43968616, 59.04644066, 52.69476515,
#        45.06589683, 43.24477712, 51.50810294, 52.47418248, 54.83033321,
#        53.99082215, 59.65334495, 48.98283952, 57.92756587, 43.6685693 ,
#        40.86117873, 49.70173317, 44.74750789, 43.359413  , 54.05349198,
#        48.64718989, 49.85771432, 44.37095645, 55.12431333, 43.10227032,
#        52.45495878, 45.63833663, 49.1092956 , 46.47312408, 54.82359117,
#        40.26652401, 53.73291379, 50.87751327, 46.0507754 , 55.58409485,
#        49.14865545, 59.2980454 , 42.43770816, 53.81813314, 50.22164183,
#        51.57423374, 50.61960692, 52.31620002, 41.29555038, 46.46313526,
#        47.36573802, 54.17254387, 48.72492417, 53.78294397, 48.32204168,
#        47.09865239, 39.79559976, 56.35960148, 44.29274065, 43.63647221,
#        45.67376481, 52.17787649, 42.74974186, 48.18443201, 55.12923379,
#        47.36499544, 50.22912114, 54.1090725 , 46.03388543, 53.081148  ,
#        43.38657551, 53.92603297, 47.3951452 , 37.83798667, 47.16587589,
#        56.91535631, 45.4531599 , 48.34958401, 44.59574642, 53.34686179,
#        62.85731683, 48.10997136, 50.62333722, 55.73107627, 51.05440591,
#        50.09303685, 50.71557289, 50.76225045, 47.3990369 , 49.84440704,
#        52.31095119, 53.41126669, 48.47275807, 51.48513364, 55.43129412,
#        44.78877074, 51.90890289, 48.35192979, 48.16127698, 50.8999173 ,
#        57.69958463, 51.6961242 , 47.51341325, 52.15775182, 45.69995309,
#        46.6887111 , 50.13857662, 41.97104977, 54.40937985, 49.10993633,
#        54.6751496 , 43.30170403, 51.93913687, 48.8122906 , 49.69682131,
#        50.54775318, 43.59234607, 55.04032326, 45.8766347 , 56.94329637,
#        44.51002328, 54.41881577, 50.68627005, 58.2898901 , 49.10836757,
#        52.04532942, 51.30885459, 48.27837772, 48.69205709, 48.22544418,
#        50.74596038, 56.06455773, 43.57496127, 42.15069509, 48.96550238,
#        52.27390208, 46.30297942, 47.95476677, 52.5253363 , 58.46237833,
#        45.8871821 , 38.79538301, 44.41799745, 49.49917771, 51.9961873 ,
#        59.83660304, 52.77772596, 53.98303891, 50.80440871, 45.4271796 ,
#        48.55553605, 51.13396672, 47.38589276, 54.43346978, 57.11628532,
#        56.74262933, 44.62578426, 44.53490349, 55.68495409, 45.64444088,
#        51.63529326, 43.23443954, 44.10973379, 56.85904264, 56.4103969 ,
#        51.51150881, 46.93525796, 46.53683211, 52.76944765, 51.24356731,
#        52.86109103, 59.25278103, 45.33493343, 46.17729098, 55.25701851,
#        50.11914463, 49.48819997, 52.071279  , 55.86794904, 58.80949428,
#        66.5873383 , 45.41345527, 49.77265962, 57.92423345, 49.26606759,
#        53.51188852, 50.22911753, 48.83277378, 54.40186907, 52.21488675,
#        56.46731399, 54.65365443, 43.11801085, 46.18431406, 49.28561165,
#        50.9466206 , 48.63903994, 53.89141129, 37.96881305, 53.56303814,
#        45.21155351, 53.72103753, 42.3979843 , 45.8415405 , 46.4840434 ,
#        46.92771343, 54.6069867 , 39.6311907 , 49.12424111, 46.18972016,
#        50.31593698, 49.31920612, 46.62584759, 50.46201044, 54.03879015,
#        45.43317742, 48.6075075 , 58.21738893, 54.04766416, 56.75884412,
#        41.73185491, 45.91156756, 51.38865923, 48.29608656, 49.75700559,
#        46.91324497, 55.11180902, 52.29924342, 32.0691111 , 49.0158075 ,
#        45.96284284, 48.49152451, 59.32020442, 46.86807756, 51.63736543,
#        54.81255804, 53.37274502, 53.01778292, 55.76880799, 47.89310367,
#        49.26865136, 53.77095167, 43.33898337, 59.32658426, 49.73592864,
#        43.74513002, 53.90161496, 47.38666661, 46.01510166, 52.16837304,
#        49.185817  , 51.01075554, 55.04829246, 49.84857456, 50.67500695,
#        47.22444806, 56.47488597, 41.66762727, 49.30640579, 58.73131392,
#        47.1866806 , 55.22187529, 48.59005031, 45.10830963, 54.24947492,
#        49.41860506, 47.5019775 , 42.71228805, 52.01283201, 52.25722965,
#        50.64983876, 53.49741037, 50.34609834, 50.76735945, 57.86323344,
#        53.35166159, 49.39402879, 45.11357428, 46.99085484, 41.98660209,
#        48.97330759, 46.26708412, 43.0009952 , 49.78420751, 47.58856561,
#        55.75718378, 51.38887992, 53.6490287 , 43.97337962, 53.37119413,
#        55.00707241, 46.81745087, 37.18531188, 46.71613869, 51.81293874,
#        45.6132576 , 55.34389554, 50.37522441, 43.52311402, 55.99242665,
#        50.24571503, 41.61433799, 52.00016123, 53.31096865, 50.03064595,
#        56.92428421, 51.19859173, 59.25807793, 56.51565854, 55.06623281,
#        54.06609138, 45.19298214, 62.9078568 , 46.6380119 , 51.77086138,
#        56.83884241, 49.35066204, 47.18064503, 44.30276406, 52.27661651,
#        46.37410462, 47.53053973, 50.76063103, 47.79446175, 47.87128242,
#        42.5339287 , 48.91490042, 49.07722715, 59.34177323, 48.0407777 ,
#        41.75736365, 53.23735036, 49.30887198, 50.74962667, 54.10841733,
#        52.06100416, 59.51231676, 49.96385361, 56.09102336, 43.88299166,
#        49.26096107, 48.55913419, 52.28339095, 45.03438589, 48.16698784,
#        69.04583964, 46.72187688, 44.95758952, 58.15531543, 52.58168659,
#        50.47573096, 60.05431   , 45.09673976, 48.84474298, 44.37355516,
#        47.11571122, 45.76613792, 54.40713532, 51.45120876, 41.39315288,
#        59.13492663, 49.02663838, 48.35335073, 49.67161944, 49.0575155 ,
#        51.31166403, 53.09341443, 51.07456025, 43.82847   , 43.70043709,
#        48.04785006, 56.04865137, 38.5054001 , 55.66649503, 53.2940292 ,
#        48.70144608, 51.67736449, 39.39775365, 56.56886354, 50.02577961,
#        45.31538063, 49.28138741, 52.31162352, 51.59380078, 52.05232184,
#        48.70833672, 50.29316296, 55.23307431, 60.21480018, 42.66971236,
#        42.2588215 , 40.14548853, 43.5418352 , 55.45825216, 48.39868875,
#        44.92574654, 49.45932622, 53.61956586, 51.54830116, 50.82478234,
#        52.78427233, 47.87775581, 59.12462504, 51.4935528 , 54.6668405 ,
#        48.98490731, 52.86230779, 43.77838651, 49.45999292, 54.33735223,
#        38.20676757, 52.34693761, 53.6157835 , 58.40341745, 51.23555895,
#        50.32081569, 41.89167396, 57.95387491, 39.66823195, 52.84715773,
#        48.40708709, 58.16855735, 57.27392422, 43.49365139, 50.334817  ,
#        55.12402424, 46.31533408, 50.66512612, 53.54688295, 49.6447365 ,
#        53.65248349, 52.9654017 , 51.32349725, 51.11816144, 48.79590435,
#        51.06325954, 49.72537895, 53.14432439, 49.32471042, 48.7608792 ,
#        41.32527292, 45.14355975, 53.34455057, 46.26796965, 38.61107296,
#        61.12948404, 48.23038616, 53.6382734 , 51.48890643, 53.02900221,
#        48.03388556, 52.530222  , 53.12106639, 52.12862849, 48.5123889 ,
#        47.3325953 , 47.36740133, 54.44500846, 51.87470093, 55.91240393,
#        42.1201078 , 47.88452447, 39.36091487, 45.13229853, 52.40335874,
#        45.4623077 , 47.9915174 , 53.19878925, 44.60868473, 50.5220172 ,
#        52.25790618, 53.44575411, 46.94746349, 53.82997736, 42.97295207,
#        53.91420049, 56.74910968, 55.60734315, 51.30884565, 50.27350527,
#        48.46470891, 52.7224094 , 51.36470364, 47.06631963, 50.56635175,
#        49.89402296, 50.60910517, 47.29682634, 51.93190877, 49.98688064,
#        53.48885689, 49.19730061, 51.23920191, 60.57139535, 52.28970111,
#        44.87232424, 51.51247092, 41.87727665, 47.77260902, 40.01332567,
#        49.13789086, 47.89821108, 48.22997745, 43.13209958, 56.15858012,
#        41.76822803, 51.05446872, 52.18602219, 46.58413619, 43.06870095,
#        47.15718363, 54.10770291, 53.79536108, 50.65600966, 53.89298506,
#        51.98176024, 43.04482447, 47.73701605, 48.74375425, 45.37480609,
#        45.38054101, 47.33049917, 53.29567545, 56.80047188, 56.96726145,
#        55.57580052, 53.36592523, 44.96331854, 50.18526898, 50.16747234,
#        47.31226753, 53.1831624 , 46.91157719, 45.5503438 , 57.49633234,
#        45.08026331, 43.1380087 , 52.62195922, 50.37364869, 54.36076306,
#        47.73816867, 52.46966835, 45.61415287, 47.30053695, 55.30303394,
#        53.15862142, 56.66038315, 52.48281684, 52.9976183 , 47.27332444,
#        48.27466664, 52.31037385, 44.68531191, 42.45334974, 47.42619829,
#        48.42604332, 49.18945096, 37.04041863, 51.02020883, 55.13668366,
#        54.32161425, 43.01190211, 45.13429504, 56.47559675, 49.57118865,
#        45.83656706, 46.87563325, 48.04452417, 48.05175623, 49.03753587,
#        45.56563186, 48.23804283, 50.4605624 , 50.90290819, 57.23676239,
#        42.83948493, 40.0990877 , 52.33179332, 42.96567888, 48.92115969,
#        50.96819177, 40.84578866, 56.84564522, 51.97940341, 48.28272299,
#        44.75380575, 51.71556872, 52.3930086 , 42.95286513, 47.43160998,
#        50.53105599, 52.81991298, 47.1490193 , 57.82858045, 56.64765965,
#        49.28178669, 48.95985048, 37.43159065, 50.32676099, 41.47053763,
#        54.34704493, 54.37546129, 50.48151124, 52.44194523, 51.22934134,
#        57.37298052, 54.54814927, 49.68332157, 47.71044021, 49.61055035,
#        52.21349556, 53.80532676, 55.34073278, 46.42288296, 49.49648722,
#        51.97362084, 46.83501705, 41.39485707, 51.82427876, 55.9608268 ,
#        43.47634313, 53.38254687, 48.90251709, 48.34188313, 50.62808713,
#        51.68206276, 56.66065389, 41.50485593, 43.17190493, 48.96235784,
#        55.30360828, 46.50104898, 49.75763612, 56.30754191, 43.69201897,
#        47.42356026, 41.41004571, 47.20444017, 48.42061078, 46.78476667,
#        59.88169759, 59.91425657, 51.41939863, 45.25070792, 50.00375112,
#        52.59316044, 45.45860622, 52.01220719, 50.42295569, 46.9589275 ,
#        56.7015    , 48.48653553, 50.99790858, 51.92119261, 50.39437465,
#        58.38440203, 52.54329746, 47.07999906, 54.67784847, 48.82852072,
#        49.02918418, 51.94411483, 52.63850098, 58.00525649, 44.27506674,
#        52.47675537, 58.94358628, 48.47413554, 58.16863265, 59.56381353,
#        57.40065943, 54.36989902, 53.24160951, 43.97229042, 51.61751514,
#        47.19711303, 53.40836331, 48.66143941, 54.22883639, 47.32428873,
#        46.84810795, 51.35189283, 42.52449294, 45.78559701, 53.94814045,
#        54.30446547, 43.31374906, 59.50843789, 47.6322445 , 49.04241526,
#        43.90565684, 45.74894373, 48.56795778, 52.22645193, 50.69308853,
#        42.6450984 , 49.87760637, 51.49269524, 49.82622075, 51.94876007,
#        47.60725999, 46.71612153, 48.39346703, 42.44615205, 47.34598929,
#        55.10567155, 53.67535932, 51.61103838, 44.30204527, 54.89859546,
#        47.29285551, 48.27823291, 48.79847308, 50.27616496, 57.54756178,
#        46.53682419, 49.26623336, 46.67725096, 52.6336868 , 57.35996746,
#        45.9409558 , 51.69344291, 49.06476019, 49.80804889, 50.62882041,
#        48.87311419, 47.94637868, 46.74377095, 56.36668111, 41.78114548,
#        38.50221916, 45.85797719, 46.78993853, 58.20669572, 55.62565086,
#        54.02892443, 58.19712942, 57.4267206 , 55.6826529 , 57.30352211,
#        53.22408985, 48.34602025, 55.78538627, 47.86252954, 47.04979157,
#        53.43443657, 47.87359568, 42.14657617, 47.58908837, 59.36226862,
#        59.48818504, 45.65552666, 50.77596629, 45.17249163, 55.87325938,
#        56.74175929, 51.78640456, 57.56146751, 38.6220277 , 57.3300264 ,
#        45.12670035, 49.55223259, 61.75665757, 57.57862303, 46.27177771,
#        35.95785429, 49.42150182, 57.39494459, 50.19773288, 55.79228732,
#        49.50332729, 58.330399  , 50.3098703 , 51.18882739, 49.33552849,
#        57.90479977, 47.41988788, 50.28793175, 51.36714634, 54.39621519,
#        50.84892072, 48.70813344, 50.55695909, 48.40328414, 40.36571212,
#        45.66075427, 58.8336375 , 42.72376007, 57.66095055, 49.08471342,
#        47.74637116, 52.41040291, 55.42244342, 42.53716607, 43.28336475,
#        42.84845157, 46.43340643, 49.50817834, 45.79462754, 46.55707003,
#        52.91544936, 59.54565189, 49.16917666, 52.62174437, 46.29636237,
#        40.98763283, 51.84336173, 54.80075229, 53.30010151, 48.52330976,
#        53.87645498, 54.59143926, 40.70030207, 41.48171977, 54.74412779,
#        49.24362669, 49.10277593, 48.48186088, 44.01504445, 51.83533239,
#        52.08294454, 51.00158414, 52.97948705, 42.11857437, 55.11093613,
#        49.7397759 , 51.82937314, 50.32968398, 48.98071914, 37.98784051,
#        42.43907738, 54.13759104, 57.47559982, 50.48370869, 57.3008638 ,
#        50.91015616, 55.26222115, 52.89769761, 48.34012634, 49.18490238,
#        53.69674548, 56.28452824, 53.90055084, 40.28168346, 48.00452778,
#        57.6668788 , 53.19661967, 46.02175976, 41.55964156, 54.16996264,
#        48.98400691, 50.51185923, 47.67073644, 45.22153868, 41.98189954,
#        53.07572396, 47.65786424, 52.60269217, 53.27679505, 52.24311806,
#        47.65014089, 51.8566174 , 50.52583224, 51.10557697, 45.48046951,
#        39.01309834, 55.88763717, 51.867218  , 43.41795024, 51.12130185,
#        62.05202167, 49.29930402, 51.92697945, 53.20761452, 50.06465032,
#        52.67232855, 58.46166155, 54.07190307, 56.95679031, 56.35586133,
#        37.83480936, 50.76581583, 47.96341555, 56.26216168, 45.16749885,
#        51.83245742, 45.13626426, 60.94054112, 55.49150355, 59.71684727,
#        54.14528397, 52.98622275, 48.26680592, 48.60195979, 43.5980191 ,
#        49.75823841, 44.82286337, 47.15887858, 52.28840639, 52.33604906,
#        50.86471906, 55.5112271 , 55.361294  , 42.40327051, 42.89113006,
#        64.46791512, 53.33358339, 48.90088678, 47.95196421, 50.51136262,
#        49.66753892, 55.85278952, 43.9210316 , 51.59760754, 51.68367984,
#        47.5771793 , 49.83520349, 49.0517881 , 50.67457545, 48.72186068,
#        48.2303426 , 44.42769217, 46.28090367, 60.42101732, 53.05406744,
#        55.07941593, 43.82462055, 57.45495696, 49.46528303, 42.36843486])

# %%
# Plotting a histogram considering 100 bins of data
plt.hist(pop_norm, bins=100, density=True);
plt.title('Histogram - 100 Bins of Data')
print('REAL mean: %.2f; std: %.2f' % (np.mean(pop_norm), np.std(pop_norm)))
# Out:
# REAL mean: 50.13; std: 4.94

# %% [markdown]
# In order to get a better side-by-side visual, we will also plot both of the histograms together

# %%
mu = 50
std = 5

norm1 = norm.rvs(mu, std, size=80)
norm2 = norm.rvs(mu, std, size=1000)

plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.hist(norm1, bins=10, density=True);
plt.hist(norm2, bins=100, density=True, color='orange', alpha=0.8)
plt.title('Histograms')
plt.legend(['Samples: 80, Bins: 10', 'Samples: 1000, Bins: 100'])

# %% [markdown]
# #### Analysis Of Data:
#
# Although we kept the mean $(\mu)$ and standard deviation $(\sigma)$ the same for both plots, it is clear that an increase in sample size and the number of bins causes a large difference in the distribution of the data. For instance, it is evident that by increasing the sample size, we are able to now view a much larger distribution/dispersion of the data including outliers on both sides of the mean even though the standard deviation remained the same (as shown in the orange overlapping histogram above). In addition, by increasing the bin size, we are also increasing the number of intervals/groups that the data can fall in which is necessary especially when increasing the sample size. This is because if the number of bins were too small or too large, the distribution/dispersion of the data would not be easily seen, and thus, the distribution trend in the data would be difficult to perceive.

# %% [markdown]
# ## **Exercise 2:**

# %% [markdown]
# First, we will load the data for an "imposter" writing of the word `Biometrics`

# %%
# data folder:
# './SampleData/biometrics/'
# './SampleData/calgary/'
# './SampleData/hello/'

# 'genuine' or 'impostor'
subdir = 'impostor/'
data_dir = './SampleData/biometrics/' + subdir

csv_file = pd.read_csv(data_dir + '1.csv')

# %% [markdown]
# After loading the data, we can visualize the first lines of data loaded which contains 4 columns [X, Y, Time, Pressure] which we will also split into separate variables

# %%
# splitting the original data/matrix into 3 variables
coord1 = csv_file[['X', 'Y']].to_numpy()
time1 = csv_file['Time'].to_numpy().reshape((-1,1))
prs1 = csv_file['Pressure'].to_numpy().reshape((-1,1))

csv_file.head()
# Out:
#            X          Y  Pressure  Time
# 0  67.631005  41.681700  0.162419     0
# 1  67.631005  40.666956  0.273965    14
# 2  67.631005  41.681700  0.180029    14
# 3  67.631005  41.681700  0.217200    14
# 4  67.631005  40.666956  0.336589    29

# %% [markdown]
# Now we will set up the matplotlib colormap in order to plot the word `Biometrics` in color representative of pressure

# %%
# to correctly map the pressure into the colormap the normalization is required 
prs1 = prs1 / np.max(prs1) * 255
prs1 = prs1.astype(int)

pressuremap = cm.get_cmap('jet', np.max(prs1)+1)
# Out:
# C:\Users\musht\AppData\Local\Temp\ipykernel_23408\1866396150.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   pressuremap = cm.get_cmap('jet', np.max(prs1)+1)

# %% [markdown]
# After setting up the colormap, we can now plot how the word `Biometrics` was written in 2D with the pressure applied being represented by color `(Red = high pressure, Blue = low pressure)`

# %%
for i in range(len(prs1)-1):
    c = pressuremap(prs1[i]).squeeze()
    
    time_diff = abs(time1[i+1] - time1[i])
    if time_diff == 0:
        time_diff = 0.0001
        
    if time_diff < 17: # You may need to change this threshould
        im = plt.plot(coord1[i:i+2,0], -coord1[i:i+2,1], c=c)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Pen pressure')

sm = cm.ScalarMappable(cmap='jet', norm=plt.Normalize(vmin=0, vmax=1))
plt.colorbar(sm);
# Out:
# C:\Users\musht\AppData\Local\Temp\ipykernel_23408\910872588.py:16: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(sm);

# %% [markdown]
# Before plotting the histogram and normal distribution, we will first calculate the mean $(\mu)$ and standard deviation $(\sigma)$ of the pressure for the word `Biometrics`

# %%
# mean and standard deviation of the presssure
mu_prs = np.mean(prs1)
std_prs = np.std(prs1)
print("Mean:", mu_prs, "Standard Deviation:", std_prs)
# Out:
# Mean: 210.82958665699783 Standard Deviation: 33.413596352704396

# %% [markdown]
# Now that we have both the mean $(\mu)$ and standard deviation $(\sigma)$, we can plot both the histogram and normal distribution

# %%
# Plotting the histogram of pressure
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
plt.hist(prs1, density=True);
plt.xlabel('Pressure', fontweight='bold')
plt.ylabel('Probability', fontweight='bold')
plt.title('Histogram', fontweight='bold')

# Plotting the normal distribution of presssure using scipy's probability density function
plt.subplot(1,2,2)
x = np.arange(0, 300, 0.01)
x_pdf = norm.pdf(x, loc=mu_prs, scale=std_prs)
plt.xlabel('Pressure', fontweight='bold')
plt.ylabel('Probability Density', fontweight='bold')
plt.title('Normal Distribution', fontweight='bold')
plt.plot(x, x_pdf);

# %% [markdown]
# #### Analysis Of Data:
#
# As shown in both the histogram and the normal distribution plots above, it is evident that most of the data is heavily distributed/dispersed in the high pressure range (150 - 250). This makes sense as we calculated the mean of the written word `Biometrics` to be $\mu = 210.89$. Moreover, as exhibited previously in the 2D colour plot, most of the letters (if not all) were written with high pressure (with the exception of small details such as the dot on top of the letter "i" and the tail-ends of the letters "t", "c", and "s"), which further explains the reasoning behind the normal distribution curved being skewed right to the high pressure range.

# %% [markdown]
# ## **Exercise 3:**

# %% [markdown]
# ## **Exercise 4:**

# %% [markdown]
# In order to perform statistical analysis of pressure and velocity distribution, we'll use average values of pressure and velocity to calculate the mean $(\mu)$ and standard deviation $(\sigma)$ of both in order to plot normal distributions

# %% [markdown]
# We'll use the function below to calculate the velocity for each signature of the genuine word `Labs` by using the time and coordinates fields

# %%
def calc_velocity(time, coords):
    vel = np.zeros((len(time)-1, 1))

    for i in range(len(time)-1):
        distance = np.sqrt((coords[i+1,0] - coords[i,0])**2 +
                           (coords[i+1,1] - coords[i,1])**2)
        
        # if too fast time_diff = 0
        time_diff = time[i+1] - time[i]
        if time_diff == 0:
            time_diff = 0.0001

        vel[i] = distance / time_diff
        vel[i] = int(vel[i] * 1000) + 1

    vel = np.insert(vel, 0, 1)
    vel = vel / np.max(vel) * 255
    vel = vel.astype(int)
    
    return vel

# %% [markdown]
# Next we will store the mean $(\mu)$ and standard deviation $(\sigma)$ of both the pressure and velocity after loading up all the samples of the word `Labs`

# %%
# columns: mean_vel, std_vec, mean_prs, std_prs
stats_measures = np.zeros((30,4))
data_dir = './Data/Usman-Labs/'

# using 30 signatures
for i in range(30):
    csv_file = pd.read_csv(data_dir + '%d.csv' % (i+1))
    
    coord1 = csv_file[['X', 'Y']].to_numpy()
    time1 = csv_file['Time'].to_numpy().reshape((-1,1))
    prs1 = csv_file['Pressure'].to_numpy().reshape((-1,1))

    vel = calc_velocity(time1, coord1)
    
    stats_measures[i, 0] = np.mean(vel)
    stats_measures[i, 1] = np.std(vel)
    
    stats_measures[i, 2] = np.mean(prs1)
    stats_measures[i, 3] = np.std(prs1)
    
    print('#%d - pressure: %.2f; velocity: %.2f' %\
          (i, np.mean(prs1), np.mean(vel)))
# Out:
# #0 - pressure: 0.67; velocity: 26.99
# #1 - pressure: 0.67; velocity: 25.06
# #2 - pressure: 0.69; velocity: 18.39
# #3 - pressure: 0.64; velocity: 15.07
# #4 - pressure: 0.67; velocity: 26.58
# #5 - pressure: 0.69; velocity: 24.95
# #6 - pressure: 0.68; velocity: 14.01
# #7 - pressure: 0.68; velocity: 20.48
# #8 - pressure: 0.69; velocity: 21.12
# #9 - pressure: 0.64; velocity: 15.85
# #10 - pressure: 0.65; velocity: 18.42
# #11 - pressure: 0.62; velocity: 16.65
# #12 - pressure: 0.66; velocity: 21.20
# #13 - pressure: 0.67; velocity: 20.29
# #14 - pressure: 0.67; velocity: 21.93
# #15 - pressure: 0.64; velocity: 16.89
# #16 - pressure: 0.63; velocity: 19.10
# #17 - pressure: 0.64; velocity: 15.52
# #18 - pressure: 0.65; velocity: 15.83
# #19 - pressure: 0.66; velocity: 20.08
# #20 - pressure: 0.68; velocity: 13.68
# #21 - pressure: 0.66; velocity: 14.89
# #22 - pressure: 0.65; velocity: 20.50
# #23 - pressure: 0.70; velocity: 27.71
# #24 - pressure: 0.69; velocity: 28.06
# #25 - pressure: 0.69; velocity: 25.22
# #26 - pressure: 0.71; velocity: 21.24
# #27 - pressure: 0.64; velocity: 28.36
# #28 - pressure: 0.63; velocity: 25.93
# #29 - pressure: 0.66; velocity: 25.90

# %% [markdown]
# Now that we have both the mean $(\mu)$ and standard deviation $(\sigma)$ of both the pressure and velocity, we can now plot normal distributions of the average pressure and velocity values across the 30 samples of the word `Labs`

# %%
# Plotting the histogram of velocity
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
plt.hist(stats_measures[:, 0], density=True);
plt.xlabel('Velocity', fontweight='bold')
plt.ylabel('Probability', fontweight='bold')
plt.title('Velocity Histogram', fontweight='bold')

# Plotting the normal distribution of velocity using scipy's probability density function
plt.subplot(1,2,2)
x = np.arange(min(stats_measures[:, 0]), max(stats_measures[:, 0]), 0.01)
x_pdf = norm.pdf(x, loc=np.mean(stats_measures[:, 0]), scale=np.std(stats_measures[:, 0]))
plt.xlabel('Velocity', fontweight='bold')
plt.ylabel('Probability Density', fontweight='bold')
plt.title('Normal Distribution of Average Velocity Values', fontweight='bold')
plt.plot(x, x_pdf);

# %%
# Plotting the histogram of pressure
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
plt.hist(stats_measures[:, 2], density=True);
plt.xlabel('Pressure', fontweight='bold')
plt.ylabel('Probability', fontweight='bold')
plt.title('Pressure Histogram', fontweight='bold')

# Plotting the normal distribution of pressure using scipy's probability density function
plt.subplot(1,2,2)
x = np.arange(min(stats_measures[:, 2]), max(stats_measures[:, 2]), 0.00125)
x_pdf = norm.pdf(x, loc=np.mean(stats_measures[:, 2]), scale=np.std(stats_measures[:, 2]))
plt.xlabel('Pressure', fontweight='bold')
plt.ylabel('Probability Density', fontweight='bold')
plt.title('Normal Distribution of Average Pressure Values', fontweight='bold')
plt.plot(x, x_pdf);

# %% [markdown]
# #### Analysis Of Data:
#
# After plotting both the histograms and normal distributions of both velocity and pressure, we were able to see some interesting trends/characteristics for the genuine signature of the word `Labs`. For instance, the mean of the velocity was $\mu = 20.86$, which translates to the normal distribution of the velocity, as most of the velocity values had the highest probability density in that area. Furthermore, the mean of the pressure was $\mu = 0.66$, and as shown in the normal distribution of the pressure above, most of the pressure values fall in this area, which means that the writer of the genuine word `Labs` applies medium-high pressure when writing.

# %% [markdown]
# ## **Exercise 5:**

# %% [markdown]
# ## **Conclusion:**
